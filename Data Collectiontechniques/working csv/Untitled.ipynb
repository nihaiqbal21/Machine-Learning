# %%
import requests
import pandas as pd

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests

url = "https://odds.p.rapidapi.com/v4/sports/americanfootball_nfl/scores"

querystring = {"daysFrom":"3"}

headers = {
	"X-RapidAPI-Key": "4a685f43b8msh85334c9bc182e25p1de185jsneba40326fb51",
	"X-RapidAPI-Host": "odds.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# [{'id': '0e7b3192b263a571917d8996f42c5024', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2023-09-08T00:20:00Z', 'completed': False, 'home_team': 'Kansas City Chiefs', 'away_team': 'Detroit Lions', 'scores': None, 'last_update': None}, {'id': '175d9f07fc52d99b21bc772b1499c3d8', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2023-09-10T17:00:00Z', 'completed': False, 'home_team': 'Washington Commanders', 'away_team': 'Arizona Cardinals', 'scores': None, 'last_update': None}, {'id': '6c2d3077c50eece8e6a37742d1ac5756', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2023-09-10T17:00:00Z', 'completed': False, 'home_team': 'Atlanta Falcons', 'away_team': 'Carolina Panthers', 'scores': None, 'last_update': None}, {'id': '33368d4979d3475b77f5e9eb49648203', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2023-09-10T17:00:00Z', 'completed': False, 'home_team': 'Baltimore Rave
# ...

# %%
df = pd.DataFrame(response.json())[['key','group','title','description','active','has_outrights']]

# %%
df
# Out:
#                                        key              group  \
# 0                     americanfootball_cfl  American Football
# 1                   americanfootball_ncaaf  American Football
# 2                     americanfootball_nfl  American Football
# 3           americanfootball_nfl_preseason  American Football
# 4   americanfootball_nfl_super_bowl_winner  American Football
# ..                                     ...                ...
# 90                    tennis_atp_wimbledon             Tennis
# 91             tennis_wta_aus_open_singles             Tennis
# 92                  tennis_wta_french_open             Tennis
# 93                      tennis_wta_us_open             Tennis
# 94                    tennis_wta_wimbledon             Tennis
#
#                     title                  description  active  has_outrights
# 0                     CFL     Canadian Football League   False          False
# ...

# %%
df.to_csv('sports.csv')
