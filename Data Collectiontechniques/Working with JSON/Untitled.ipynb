# %%
import pandas as pd

# %% [markdown]
# # Working with JSON

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('https://newsapi.org/v2/top-headlines?category=science&apiKey=4e3d3f365e6e4c68826040f69ae9f151')
# Out:
#    status  totalResults                                           articles
# 0      ok          1000  {'source': {'id': None, 'name': 'Devdiscourse'...
# 1      ok          1000  {'source': {'id': 'google-news', 'name': 'Goog...
# 2      ok          1000  {'source': {'id': 'google-news', 'name': 'Goog...
# 3      ok          1000  {'source': {'id': None, 'name': 'Moneycontrol'...
# 4      ok          1000  {'source': {'id': 'google-news', 'name': 'Goog...
# 5      ok          1000  {'source': {'id': 'google-news', 'name': 'Goog...
# 6      ok          1000  {'source': {'id': 'google-news', 'name': 'Goog...
# 7      ok          1000  {'source': {'id': None, 'name': 'ScienceAlert'...
# 8      ok          1000  {'source': {'id': 'google-news', 'name': 'Goog...
# 9      ok          1000  {'source': {'id': 'google-news', 'name': 'Goog...
# 10     ok          1000  {'source': {'id': 'google-news', 'name': 'Goog...
# ...

# %% [markdown]
# # Working with SQL

# %%
# !pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 11.9/11.9 MB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp39-cp39-win_amd64.whl size=247946 sha256=61cbdd49fc991e123f72b994a5fc1d28f595758f25bd50b05f216fc78ce1199d
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\7b\14\39\5aad423666e827dfe9a1fbcd111ac17171e7c9865d570780ce
# Successfully built mysql.connector
# ...

# %%
import mysql.connector

# %%
sq = mysql.connector.connect(host='localhost', user='root', password='', database='world')

# %%
df = pd.read_sql_query("SELECT * FROM city", sq)

# %%
df
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
 pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'AFG'", sq)
# Out:
#    ID            Name CountryCode  District  Population
# 0   1           Kabul         AFG     Kabol     1780000
# 1   2        Qandahar         AFG  Qandahar      237500
# 2   3           Herat         AFG     Herat      186800
# 3   4  Mazar-e-Sharif         AFG     Balkh      127800

# %%
 pd.read_sql_query("SELECT * FROM country", sq)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# ...

# %%
 pd.read_sql_query("SELECT * FROM country WHERE Continent LIKE 'Asia'", sq)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    Code                  Name Continent                     Region  \
# 0   AFG           Afghanistan      Asia  Southern and Central Asia
# 1   ARE  United Arab Emirates      Asia                Middle East
# 2   ARM               Armenia      Asia                Middle East
# 3   AZE            Azerbaijan      Asia                Middle East
# 4   BGD            Bangladesh      Asia  Southern and Central Asia
# 5   BHR               Bahrain      Asia                Middle East
# 6   BRN                Brunei      Asia             Southeast Asia
# 7   BTN                Bhutan      Asia  Southern and Central Asia
# 8   CHN                 China      Asia               Eastern Asia
# ...
