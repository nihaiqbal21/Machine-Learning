# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('Breast_Cancer.csv')

# %%
df
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %% [markdown]
# # How big data is?

# %%
df.shape
# Out:
# (4024, 16)

# %% [markdown]
# # How does data look like?

# %%
df.sample(10)
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 3412   48  Black        Married       T2      N1       IIB
# 1350   59  White        Married       T1      N1       IIA
# 2538   47  White       Divorced       T2      N1       IIB
# 544    52  White       Divorced       T1      N3      IIIC
# 1807   54  White        Married       T2      N3      IIIC
# 3777   52  White        Married       T1      N1       IIA
# 3937   64  White        Married       T1      N1       IIA
# 1328   56  White        Single        T2      N1       IIB
# 2984   68  White        Single        T2      N3      IIIC
# 363    51  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 3412  Moderately differentiated     2  Regional          24        Positive
# 1350  Moderately differentiated     2  Regional          20        Negative
# 2538  Moderately differentiated     2  Regional          37        Positive
# ...

# %% [markdown]
# # what is data type of cols?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     4024 non-null   int64
#  1   Race                    4024 non-null   object
#  2   Marital Status          4024 non-null   object
#  3   T Stage                 4024 non-null   object
#  4   N Stage                 4024 non-null   object
#  5   6th Stage               4024 non-null   object
#  6   differentiate           4024 non-null   object
#  7   Grade                   4024 non-null   object
#  8   A Stage                 4024 non-null   object
#  9   Tumor Size              4024 non-null   int64
#  10  Estrogen Status         4024 non-null   object
#  11  Progesterone Status     4024 non-null   object
#  12  Regional Node Examined  4024 non-null   int64
#  13  Reginol Node Positive   4024 non-null   int64
# ...

# %% [markdown]
# # are there any missing values?

# %%
df.isnull().sum()
# Out:
# Age                       0
# Race                      0
# Marital Status            0
# T Stage                   0
# N Stage                   0
# 6th Stage                 0
# differentiate             0
# Grade                     0
# A Stage                   0
# Tumor Size                0
# Estrogen Status           0
# Progesterone Status       0
# Regional Node Examined    0
# Reginol Node Positive     0
# Survival Months           0
# Status                    0
# dtype: int64

# %% [markdown]
# # how does data look like mathematically?

# %%
df.describe()
# Out:
#                Age   Tumor Size  Regional Node Examined  \
# count  4024.000000  4024.000000             4024.000000
# mean     53.972167    30.473658               14.357107
# std       8.963134    21.119696                8.099675
# min      30.000000     1.000000                1.000000
# 25%      47.000000    16.000000                9.000000
# 50%      54.000000    25.000000               14.000000
# 75%      61.000000    38.000000               19.000000
# max      69.000000   140.000000               61.000000
#
#        Reginol Node Positive  Survival Months
# count            4024.000000      4024.000000
# mean                4.158052        71.297962
# std                 5.109331        22.921430
# min                 1.000000         1.000000
# 25%                 1.000000        56.000000
# 50%                 2.000000        73.000000
# 75%                 5.000000        90.000000
# max                46.000000       107.000000

# %% [markdown]
# # are there any duplicate values?

# %%
df.duplicated().sum()
# Out:
# 1

# %% [markdown]
# # How is colrrelation b/w cols?

# %%
df.corr()
# Out:
#                              Age  Tumor Size  Regional Node Examined  \
# Age                     1.000000   -0.077215               -0.033345
# Tumor Size             -0.077215    1.000000                0.104352
# Regional Node Examined -0.033345    0.104352                1.000000
# Reginol Node Positive   0.012586    0.242322                0.411580
# Survival Months        -0.009390   -0.086901               -0.022054
#
#                         Reginol Node Positive  Survival Months
# Age                                  0.012586        -0.009390
# Tumor Size                           0.242322        -0.086901
# Regional Node Examined               0.411580        -0.022054
# Reginol Node Positive                1.000000        -0.135214
# Survival Months                     -0.135214         1.000000

# %%
sns.countplot(df['Status'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Status', ylabel='count'>

# %%
df['Status'].value_counts()
# Out:
# Alive    3408
# Dead      616
# Name: Status, dtype: int64

# %%
(df['Status'].value_counts()).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
(df['Marital Status'].value_counts()).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Status'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='Status'>

# %%
plt.hist(df['Age'])
# Out:
# (array([ 47.,  86., 240., 355., 626., 565., 558., 550., 540., 457.]),
#  array([30. , 33.9, 37.8, 41.7, 45.6, 49.5, 53.4, 57.3, 61.2, 65.1, 69. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Survival Months'], bins=10)
# Out:
# (array([ 65.,  92., 103., 141., 432., 680., 654., 607., 622., 628.]),
#  array([  1. ,  11.6,  22.2,  32.8,  43.4,  54. ,  64.6,  75.2,  85.8,
#          96.4, 107. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Survival Months'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Survival Months', ylabel='Density'>

# %%
sns.boxplot(df['Age'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(df['Survival Months'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Survival Months'>

# %%
df['Survival Months'].min()
# Out:
# 1

# %%
df['Survival Months'].max()
# Out:
# 107

# %%
df['Survival Months'].mean()
# Out:
# 71.29796222664015

# %%
df['Age'].min()
# Out:
# 30

# %%
df['Age'].max()
# Out:
# 69

# %%
df['Age'].mean()
# Out:
# 53.97216699801193

# %%
df['Survival Months'].skew()
# Out:
# -0.589998326716996

# %%
df['Age'].skew()
# Out:
# -0.2203727859678868

# %%
df
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %%
sns.scatterplot(x= 'Age', y='Survival Months', data= df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Survival Months'>

# %%
sns.scatterplot(x= 'Age', y='Regional Node Examined', data= df, hue= df['Reginol Node Positive'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Regional Node Examined'>

# %%
sns.scatterplot(df['Marital Status'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Marital Status'>

# %%
sns.pairplot(df, hue= 'Grade')

# %%
df
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %%
#sns.barplot(x= 'Marital Status', y='Tumor Size', data=df)

# %%
sns.boxplot(x= 'Survival Months', y='Grade', data=df)
# Out:
# <AxesSubplot:xlabel='Survival Months', ylabel='Grade'>

# %%
sns.distplot(df[df['Status']=='Alive']['Age'], hist=False)
sns.distplot(df[df['Status']=='Dead']['Age'], hist=False)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.heatmap(pd.crosstab(df['Marital Status'], df['Progesterone Status']))
# Out:
# <AxesSubplot:xlabel='Progesterone Status', ylabel='Marital Status'>

# %%
sns.heatmap(pd.crosstab(df['Status'], df['Grade']))
# Out:
# <AxesSubplot:xlabel='Grade', ylabel='Status'>

# %%
df
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %%
sns.heatmap(df.pivot_table(values='Survival Months', index='Marital Status', columns='Status'))
# Out:
# <AxesSubplot:xlabel='Status', ylabel='Marital Status'>

# %%
sns.clustermap(pd.crosstab(df['Marital Status'], df['Progesterone Status']))

# %%
new=df.groupby('Survival Months').sum().reset_index()

# %%
new
# Out:
#      Survival Months   Age  Tumor Size  Regional Node Examined  \
# 0                  1    43          40                      19
# 1                  2   160          89                      55
# 2                  3   231         104                      51
# 3                  4   605         317                     125
# 4                  5   264         166                      54
# ..               ...   ...         ...                     ...
# 102              103  2630        1320                     739
# 103              104  2668        1595                     651
# 104              105  2311        1527                     637
# 105              106  2478        1331                     613
# 106              107  3265        1722                     872
#
#      Reginol Node Positive
# 0                       11
# 1                       11
# 2                       18
# 3                       57
# 4                       13
# ..                     ...
# ...

# %%
sns.lineplot(new['Survival Months'], new['Tumor Size'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Survival Months', ylabel='Tumor Size'>

# %%
from pandas_profiling import ProfileReport
prof= ProfileReport(df)
prof.to_file('breastcancer_report.html')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_964\1352807658.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
